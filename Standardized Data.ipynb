# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Veri setini yükle
df = pd.read_csv("SayısalnewdatasetLyricli.csv")

# Sadece sayısal sütunları seç
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

# Standartlaştırma işlemi için StandardScaler'ı kullan
scaler = StandardScaler()
standardized_data = scaler.fit_transform(numeric_columns)

# Standartlaştırılmış veriyi DataFrame'e dönüştür
standardized_df = pd.DataFrame(standardized_data, columns=numeric_columns.columns)

# Sonuçları göster
print("Standartlaştırılmış Veri:")
#print(standardized_df)
standardized_df
# Out:
# Standartlaştırılmış Veri:
#       Track Name    Artist  Artist Popularity  Artist Genres  \
# 0       1.716525 -1.539487           0.872925       1.074421
# 1       0.765411  0.924653           0.950769       1.180143
# 2      -1.013595  1.328610           1.339987      -0.863825
# 3       0.857827  0.520695           0.717238       1.259435
# 4       1.697271  0.574556           0.795082       1.074421
# ...          ...       ...                ...            ...
# 1136    0.064591 -0.065043          -4.342591       1.506121
# 1137    1.601005 -0.132369          -0.761789      -0.529037
# 1138    0.896334  1.463262          -3.641999       1.506121
# 1139    0.830872 -0.893155          -2.240816      -0.467366
# 1140   -0.613126 -0.502663          -1.695911      -0.502607
#
#       Track Duration(ms)  Release Date  Track Popularity  Danceability  \
# 0               0.160680      1.362587          1.115239      0.997613
# 1              -0.129289      0.831263          1.014900     -0.570628
# 2               0.553262      0.915497          0.412872     -0.762378
# 3              -0.556837      0.772947          1.215577      0.134738
# 4               0.264633      1.077486         -1.844734     -0.899343
# ...                  ...           ...               ...           ...
# 1136            0.270699     -0.950615         -1.593889     -0.659655
# 1137            0.627304      0.014839         -1.593889     -0.372030
# 1138           -0.955770     -0.665515         -1.593889      0.785318
# 1139            1.478664      0.436010         -1.593889     -0.125495
# 1140            0.079342      0.163869         -1.644058     -0.139191
#
#         Energy       Key  Loudness      Mode  Speechiness  Acousticness  \
# 0     0.755254 -1.082008  0.071718  0.760360    -0.398126     -0.188859
# 1    -0.412620  0.005241 -0.203141  0.760360     0.557672     -0.401625
# 2    -0.559309 -1.082008  0.076695 -1.315167    -0.203448     -0.061946
# 3    -0.768059  1.092490 -0.074133  0.760360    -0.190548      1.991059
# 4    -0.519816  0.005241  0.365718  0.760360    -0.333625     -0.297108
# ...        ...       ...       ...       ...          ...           ...
# 1136 -0.756776  1.364302 -0.114711  0.760360    -0.629160      0.322526
# 1137 -2.093906  1.364302 -0.803773  0.760360    -0.644405      2.162765
# 1138 -1.885156  0.820677  0.185030  0.760360    -0.610395      2.267282
# 1139 -1.631270 -1.082008 -0.752859  0.760360    -0.633851      1.681242
# 1140  0.264408 -0.266571  0.600382  0.760360    -0.601013     -0.658810
#
#       Instrumentalness  Liveness   Valence     Tempo  Time_signature
# 0            -0.185503 -0.502910  1.439340 -0.059820        0.190627
# 1            -0.186540 -0.454099 -0.417751  0.782458        0.190627
# 2            -0.186540  2.238608  0.056216 -1.888546        0.190627
# 3            -0.186540 -0.519180  1.413487 -0.098249        0.190627
# 4            -0.186540  1.181049 -0.719367  0.600631        0.190627
# ...                ...       ...       ...       ...             ...
# 1136         -0.186540 -0.535450 -0.499618  1.439961        0.190627
# 1137         -0.186540 -0.585887 -1.154555  0.577925        0.190627
# 1138         -0.186540 -0.635511 -1.133011  0.080419        0.190627
# 1139         -0.171162 -0.637952 -0.710749 -1.796702        0.190627
# 1140         -0.186540  0.025870 -1.072688 -1.429820        0.190627
#
# [1141 rows x 19 columns]
