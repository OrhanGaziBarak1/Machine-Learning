# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# CSV dosyasından şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_youtube_urls(input_csv_file):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Sadece 1-50. satırları oku
        for row_number, row in enumerate(csv_reader, start=10):
            if row_number > 50:
                break
            
            song_name = row['Track Name']
            artist_name = row['Artist']
            youtube_url = get_youtube_url(song_name)
            youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# track_artist.csv dosyasından sadece 1-50. satırları okuyarak YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
youtube_urls = get_youtube_urls(input_csv_file)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in youtube_urls:
        writer.writerow(data)

print(f"Veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# Veriler 'track_artist_yturl.csv' dosyasına kaydedildi.

# %%
install pip build
# Out:
#   Cell In[2], line 1
#     install pip build
#             ^
# SyntaxError: invalid syntax

# %%
install build
# Out:
#   Cell In[3], line 1
#     install build
#             ^
# SyntaxError: invalid syntax

# %%
pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/c6/5a/8285f25d8bfe1586cf543e816e4c371e8c01826af49ef8a0d098b2cfa32c/google_api_python_client-2.121.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.121.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting httplib2<1.dev0,>=0.15.0 (from google-api-python-client)
#   Obtaining dependency information for httplib2<1.dev0,>=0.15.0 from https://files.pythonhosted.org/packages/a8/6c/d2fbdaaa5959339d53ba38e94c123e4e84b8fbc4b84beb0e70d7c1608486/httplib2-0.22.0-py3-none-any.whl.metadata
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth<3.0.0.dev0,>=1.19.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth<3.0.0.dev0,>=1.19.0 from https://files.pythonhosted.org/packages/b7/1d/f152a5f6d243b6acbb2a710ed19aa47154d678359bed995abdd9daf0cff0/google_auth-2.28.1-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.28.1-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2>=0.1.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth-httplib2>=0.1.0 from https://files.pythonhosted.org/packages/be/8a/fe34d2f3f9470a27b01c9e76226965863f153d5fbe276f83608562e49c04/google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/0f/87/373ab788a4682adc1a6900e54d54c750b7bd4be456d75b8bf64eccc23ef9/google_api_core-2.17.1-py3-none-any.whl.metadata
#   Downloading google_api_core-2.17.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Obtaining dependency information for uritemplate<5,>=3.0.1 from https://files.pythonhosted.org/packages/81/c0/7461b49cd25aeece13766f02ee576d1db528f1c37ce69aee300e075b485b/uritemplate-4.1.1-py2.py3-none-any.whl.metadata
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/f0/43/c9d8f75ddf08e2a0a27db243c13a700c3cc7ec615b545b697cf6f715ad92/googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 from https://files.pythonhosted.org/packages/f3/bf/26deba06a4c910a85f78245cac7698f67cedd7efe00d04f6b3e1b3506a59/protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/fb/2b/a64c2d25a37aeb921fddb929111413049fc5f8b9a4c1aefaffaafe768d54/cachetools-5.3.3-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ardilsilanaydin/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Downloading google_api_python_client-2.121.0-py2.py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 12.9 MB/s eta 0:00:0000:0100:01
# Downloading google_api_core-2.17.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 11.6 MB/s eta 0:00:00
# Downloading google_auth-2.28.1-py2.py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.9/186.9 kB 8.5 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 4.5 MB/s eta 0:00:00
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 6.5 MB/s eta 0:00:00
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Installing collected packages: uritemplate, rsa, protobuf, httplib2, cachetools, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.3.3 google-api-core-2.17.1 google-api-python-client-2.121.0 google-auth-2.28.1 google-auth-httplib2-0.2.0 googleapis-common-protos-1.62.0 httplib2-0.22.0 protobuf-4.25.3 rsa-4.9 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# CSV dosyasından şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_youtube_urls(input_csv_file):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Sadece 1-50. satırları oku
        for row_number, row in enumerate(csv_reader, start=20):
            if row_number > 50:
                break
            
            song_name = row['Track Name']
            artist_name = row['Artist']
            youtube_url = get_youtube_url(song_name)
            youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# track_artist.csv dosyasından sadece 1-50. satırları okuyarak YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
youtube_urls = get_youtube_urls(input_csv_file)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in youtube_urls:
        writer.writerow(data)

print(f"Veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Blinding+Lights&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=redrum&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Blueberry+Faygo&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Levitating+%28feat.+DaBaby%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=MONTERO+%28Call+Me+By+Your+Name%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=drivers+license&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=What+Was+I+Made+For%3F+%5BFrom+The+Motion+Picture+%22Barbie%22%5D&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Woman&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Veriler 'track_artist_yturl.csv' dosyasına kaydedildi.

# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# CSV dosyasından şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_youtube_urls(input_csv_file):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        # Sadece 1-50. satırları oku
        for row_number, row in enumerate(csv_reader, start=1):
            if start_row <= row_number <= end_row:
                song_name = row['Track Name']
                artist_name = row['Artist']
                youtube_url = get_youtube_url(song_name)
                youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# track_artist.csv dosyasından 50. satırdan 100. satıra kadar olan şarkıların YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
start_row = 139
end_row = 185
range_youtube_urls = get_range_youtube_urls(input_csv_file, start_row, end_row)

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# track_artist.csv dosyasından sadece 1-50. satırları okuyarak YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
youtube_urls = get_youtube_urls(input_csv_file)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in youtube_urls:
        writer.writerow(data)

print(f"Veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 32
#      30 start_row = 139
#      31 end_row = 185
# ---> 32 range_youtube_urls = get_youtube_urls(input_csv_file, start_row, end_row)
#      34 # YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
#      35 def get_youtube_url(song_name):
#
# TypeError: get_youtube_urls() takes 1 positional argument but 3 were given

# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# CSV dosyasından belirli aralıktaki şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_range_youtube_urls(input_csv_file, start_row, end_row):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        for row_number, row in enumerate(csv_reader, start=1):
            if start_row <= row_number <= end_row:
                song_name = row['Track Name']
                artist_name = row['Artist']
                youtube_url = get_youtube_url(song_name)
                youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# track_artist.csv dosyasından 50. satırdan 100. satıra kadar olan şarkıların YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
start_row = 50
end_row = 100
range_youtube_urls = get_range_youtube_urls(input_csv_file, start_row, end_row)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'range_track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in range_youtube_urls:
        writer.writerow(data)

print(f"Aralık veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Rich+Flex&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=One+Of+The+Girls+%28with+JENNIE%2C+Lily+Rose+Depp%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=FTCU&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Quevedo%3A+Bzrp+Music+Sessions%2C+Vol.+52&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Love+On&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Toosie+Slide&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Rain+On+Me+%28with+Ariana+Grande%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Yummy&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Holy+%28feat.+Chance+The+Rapper%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Prisoner+%28feat.+Dua+Lipa%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Physical&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=POPSTAR+%28feat.+Drake%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Fair+Trade+%28with+Travis+Scott%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Butter&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Kiss+Me+More+%28feat.+SZA%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=INDUSTRY+BABY+%28feat.+Jack+Harlow%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Need+to+Know&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Bad+Habits&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=pov&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=willow&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=You+Right&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=THATS+WHAT+I+WANT&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Is+There+Someone+Else%3F&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Late+Night+Talking&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Left+and+Right+%28Feat.+Jung+Kook+of+BTS%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Lavender+Haze&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Ghost&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Out+of+Time&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Bam+Bam+%28feat.+Ed+Sheeran%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Shakira%3A+Bzrp+Music+Sessions%2C+Vol.+53&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Ella+Baila+Sola&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Paint+The+Town+Red&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Calm+Down+%28with+Selena+Gomez%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Daylight&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Karma&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Popular+%28with+Playboi+Carti+%26+Madonna%29+-+From+The+Idol+Vol.+1+%28Music+from+the+HBO+Original+Series%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=bad+idea+right%3F&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=drivers+license&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Good+Days&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Peaches+%28feat.+Daniel+Caesar+%26+Giveon%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Save+Your+Tears+%28with+Ariana+Grande%29+%28Remix%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Woman&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=34%2B35&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=love+nwantiti+%28ah+ah+ah%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Heartbreak+Anniversary&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Fair+Trade+%28with+Travis+Scott%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=MONTERO+%28Call+Me+By+Your+Name%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Beggin%27&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Levitating+%28feat.+DaBaby%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Butter&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Kiss+Me+More+%28feat.+SZA%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Aralık veriler 'range_track_artist_yturl.csv' dosyasına kaydedildi.

# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyChB-YPpJfWIxzUIV5oGyMjuSjieN7W6FI'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# CSV dosyasından belirli aralıktaki şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_range_youtube_urls(input_csv_file, start_row, end_row):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        for row_number, row in enumerate(csv_reader, start=1):
            if start_row <= row_number <= end_row:
                song_name = row['Track Name']
                artist_name = row['Artist']
                youtube_url = get_youtube_url(song_name)
                youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# track_artist.csv dosyasından 50. satırdan 100. satıra kadar olan şarkıların YouTube URL'lerini al
input_csv_file = 'track_artist.csv'
start_row = 188
end_row = 239
range_youtube_urls = get_range_youtube_urls(input_csv_file, start_row, end_row)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'range_track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in range_youtube_urls:
        writer.writerow(data)

print(f"Aralık veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Ghost&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=THATS+WHAT+I+WANT&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Lavender+Haze&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Envolver&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=DESPECH%C3%81&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Me+Porto+Bonito&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=traitor&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Out+of+Time&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Massive&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Cold+Heart+-+PNAU+Remix&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Super+Freaky+Girl&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Boyfriend&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Pink+Venom&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=INDUSTRY+BABY+%28feat.+Jack+Harlow%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Shirt&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=I+Ain%27t+Worried&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Bam+Bam+%28feat.+Ed+Sheeran%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=La+Bachata&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=PROVENZA&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=MIDDLE+OF+THE+NIGHT&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Enemy+%28with+JID%29+-+from+the+series+Arcane+League+of+Legends&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Jimmy+Cooks+%28feat.+21+Savage%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=I+Like+You+%28A+Happier+Song%29+%28with+Doja+Cat%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Oh+My+God&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=We+Don%27t+Talk+About+Bruno&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Una+Noche+en+Medell%C3%ADn&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=All+For+Us&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Where+Are+You+Now&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=STAR+WALKIN%27+%28League+of+Legends+Worlds+Anthem%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Infinity&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=MAMIII&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Sacrifice&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Sweetest+Pie&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Ojitos+Lindos&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Lift+Me+Up+-+From+Black+Panther%3A+Wakanda+Forever+-+Music+From+and+Inspired+By&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Snow+On+The+Beach+%28feat.+Lana+Del+Rey%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=One+Right+Now+%28with+The+Weeknd%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=BREAK+MY+SOUL&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Woman&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Te+Felicito&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Shut+Down&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Save+Your+Tears+%28Remix%29+%28with+Ariana+Grande%29+-+Bonus+Track&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=STAY+%28with+Justin+Bieber%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=When+You%27re+Gone&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=The+Joker+And+The+Queen+%28feat.+Taylor+Swift%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=I%E2%80%99m+Tired+%28with+Zendaya%29+-+Bonus+Track&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Notion&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Light+Switch&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=Nail+Tech&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=N95&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# YouTube API Error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&q=WAIT+FOR+U+%28feat.+Drake+%26+Tems%29&type=video&maxResults=1&key=AIzaSyBcQgjtZr_oyXYdcwToGoCUfK2gH_OpWqE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Aralık veriler 'range_track_artist_yturl.csv' dosyasına kaydedildi.

# %%
import csv
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# YouTube API anahtarınızı buraya girin
API_KEY = 'AIzaSyDKcWLDd8DSIAE6BbKUpqJU706A6dk1jyE'

# YouTube API'sini yapılandır
youtube = build('youtube', 'v3', developerKey=API_KEY)

# YouTube araması yaparak şarkı ismine göre URL almak için bir fonksiyon
def get_youtube_url(song_name):
    try:
        # YouTube API'sini kullanarak arama yap
        request = youtube.search().list(
            part='snippet',
            q=song_name,
            type='video',
            maxResults=1
        )
        response = request.execute()

        # İlk sonucu kontrol et ve URL'yi döndür
        if 'items' in response:
            video_id = response['items'][0]['id']['videoId']
            youtube_url = f'https://www.youtube.com/watch?v={video_id}'
            return youtube_url
        else:
            return None

    except HttpError as e:
        print(f'YouTube API Error: {e}')
        return None

# CSV dosyasından belirli aralıktaki şarkı isimlerini ve URL'leri almak için bir fonksiyon
def get_range_youtube_urls(input_csv_file, start_row, end_row):
    youtube_urls = []

    with open(input_csv_file, 'r', newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        for row_number, row in enumerate(csv_reader, start=1):
            if start_row <= row_number <= end_row:
                song_name = row['Track Name']
                artist_name = row['Artist']
                youtube_url = get_youtube_url(song_name)
                youtube_urls.append({'Track Name': song_name, 'Artist Name': artist_name, 'YouTube URL': youtube_url})

    return youtube_urls

# track_artist.csv dosyasından 50. satırdan 100. satıra kadar olan şarkıların YouTube URL'lerini al
input_csv_file = 'eşleşmeyenler_2sütun.csv'
start_row = 1
end_row = 50
range_youtube_urls = get_range_youtube_urls(input_csv_file, start_row, end_row)

# Alınan URL'leri CSV dosyasına kaydet
output_csv_file = 'range_track_artist_yturl.csv'
with open(output_csv_file, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Track Name', 'Artist Name', 'YouTube URL']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for data in range_youtube_urls:
        writer.writerow(data)

print(f"Aralık veriler '{output_csv_file}' dosyasına kaydedildi.")
# Out:
# Aralık veriler 'range_track_artist_yturl.csv' dosyasına kaydedildi.
