# %%
import pandas as pd

# %%
veri = pd.read_csv("playlist_dataset(lyrics)_new_kopyası.csv")

# %%
veri.head()
# Out:
#             Track Name          Artist                             Artist URI  \
# 0            yes, and?   Ariana Grande  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR
# 1               Snooze             SZA  spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 2  Die For You - Remix      The Weeknd  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 3         Stick Season      Noah Kahan  spotify:artist:2RQXRUsr4IW1f3mKyKsy4B
# 4              vampire  Olivia Rodrigo  spotify:artist:1McMsnEElThX1knmY4oliG
#
#    Artist Popularity                                 Artist Genres  \
# 0                 89                                           pop
# 1                 90                                 pop, r&b, rap
# 2                 95  canadian contemporary r&b, canadian pop, pop
# 3                 87                                    pov: indie
# 4                 88                                           pop
#
#    Track Duration(ms) Release Date  Track Popularity  Danceability  Energy  \
# ...

# %%
print(veri)
# Out:
#                                          Track Name            Artist  \
# 0                                         yes, and?     Ariana Grande
# 1                                            Snooze               SZA
# 2                               Die For You - Remix        The Weeknd
# 3                                      Stick Season        Noah Kahan
# 4                                           vampire    Olivia Rodrigo
# ...                                             ...               ...
# 1136                                     Miles Away       Krysta Nick
# 1137  half of my hometown - ballerini album version  Kelsea Ballerini
# 1138                                 Suitcase Heart        Tyler Cain
# 1139                                      St. Louis        David Nail
# 1140                                      Heartland   Hailey Whitters
#
#                                  Artist URI  Artist Popularity  \
# ...

# %%
veri.describe()
# Out:
#        Artist Popularity  Track Duration(ms)  Track Popularity  Danceability  \
# count        1141.000000         1141.000000       1141.000000   1141.000000
# mean           77.786152       207682.829974         73.770377      0.642325
# std            12.851917        45521.286882         19.941358      0.146088
# min            22.000000        91554.000000          0.000000      0.122000
# 25%            71.000000       178360.000000         69.000000      0.546000
# 50%            80.000000       204033.000000         80.000000      0.650000
# 75%            87.000000       232373.000000         87.000000      0.750000
# max           100.000000       613026.000000         99.000000      0.967000
#
#             Energy          Key     Loudness         Mode  Speechiness  \
# count  1141.000000  1141.000000  1141.000000  1141.000000  1141.000000
# mean      0.624135     4.980719    -6.700345     0.633655     0.084448
# ...

# %%
veri_seti = pd.read_csv('playlist_dataset(lyrics)_new_kopyası.csv')

# Tekrarlanan satırları sil
temiz_veri_seti = veri.drop_duplicates()

# Sonucu yeni bir CSV dosyasına yaz
temiz_veri_seti.to_csv('temizlenmis_dosya_adı.csv', index=False)
temiz_veri_seti = temiz_veri_seti.sort_values(by='Track Name')

# %%
temiz_veri_seti.head()
# Out:
#                         Track Name                Artist  \
# 326   (It Goes Like) Nanana - Edit             Peggy Gou
# 775                       02.02.99       That Mexican OT
# 972               1st of Tha Month  Bone Thugs-N-Harmony
# 1098                          2016              Sam Hunt
# 822                             23        Chayce Beckham
#
#                                  Artist URI  Artist Popularity  \
# 326   spotify:artist:2mLA48B366zkELXYx7hcDN                 69
# 775   spotify:artist:3BAgmPNIK5IJl7zMK1wvMA                 71
# 972   spotify:artist:5spEJXLwD1sKUdC2bnOHPg                 65
# 1098  spotify:artist:2kucQ9jQwuD8jWdtR9Ef38                 68
# 822   spotify:artist:5ujvZU2thXjZgFKPUt1rDt                 61
#
#                                           Artist Genres  Track Duration(ms)  \
# 326                                electra, float house              231545
# 775                                     texas latin rap              162162
# ...

# %%
temiz_veri_seti = pd.read_csv('temizlenmis_dosya_adı.csv')
temiz_veri_seti_alfabetik = temiz_veri_seti.sort_values(by='Track Name')
temiz_veri_seti_alfabetik.to_csv('temizlenmis_dosya_adı_alfabestik.csv', index=False)
