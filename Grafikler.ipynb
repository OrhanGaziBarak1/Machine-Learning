# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
veri = pd.read_csv("final_dataset.csv")

# %%
veri.rename(columns = {"Artist Popularity" : "Artist_Popularity",
                       "Artist Genres": "Artist_Genres",
                       "Release Date" : "Release_Date",
                       "Track Popularity" : "Track_Popularity"}, inplace= True)
veri.head()
# Out:
#                                           Sound Path  \
# 0  mp3_tracks/Is It Over Now? (Taylor's Version) ...
# 1                             mp3_tracks/Houdini.mp3
# 2                     mp3_tracks/bad idea right?.mp3
# 3  mp3_tracks/"Slut!" (Taylor's Version) (From Th...
# 4                  mp3_tracks/Boy's a liar Pt. 2.mp3
#
#                                           Track Name          Artist  \
# 0  Is It Over Now? (Taylor's Version) (From The V...    Taylor Swift
# 1                                            Houdini        Dua Lipa
# 2                                    bad idea right?  Olivia Rodrigo
# 3        "Slut!" (Taylor's Version) (From The Vault)    Taylor Swift
# 4                                 Boy's a liar Pt. 2  PinkPantheress
#
#                               Artist URI  Artist_Popularity  \
# 0  spotify:artist:06HL4z0CvFAxyc27GXpf02                100
# 1  spotify:artist:6M2wZ9GZgrQXHCFfjv46we                 86
# ...

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Artist_Popularity, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Artist_Popularity,palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Artist_Popularity, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Track_Popularity, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Track_Popularity, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Track_Popularity, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Danceability, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Danceability, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Danceability, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Key, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Key, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Key, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Loudness, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Loudness, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Loudness, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Mode, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Mode, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Mode, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Speechiness, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Speechiness, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Speechiness, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Acousticness, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Acousticness, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Acousticness, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Instrumentalness, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Instrumentalness, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Instrumentalness, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Valence, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Valence, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Valence, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Tempo, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Tempo, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Tempo, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()

# %%
plt.subplot(131)
plt.title('Plot Histogram')
plt.hist(veri.Duration_ms, color = "g")

plt.subplot(132)
plt.title('Box-Plot')
sns.boxplot(veri.Duration_ms, palette="Set3")

plt.subplot(133)
plt.title('Violin Plot')
sns.violinplot(veri.Duration_ms, linewidth=5, palette="Set2")
plt.show()
plt.tight_layout()
